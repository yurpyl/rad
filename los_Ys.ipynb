# %% [markdown]
# <a href="https://colab.research.google.com/github/yurpyl/rad/blob/main/los_Ys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install igraph
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 11.9 MB/s eta 0:00:00
# ...

# %%
import igraph as ig
import json
import urllib3
import plotly as py
import plotly.graph_objs as go

data = []

dataY = {
    "nodes": [{
        "name": "LINAC",
        "group": 1,
        "index": 0
    }, {
        "name": "Regelverk",
        "group": 1,
        "inbeadex": 1
    }, {
        "name": "Relative Dosimetry",
        "group": 1,
        "index": 2
    }, {
        "name": "Dosimetry",
        "group": 1,
        "index": 3
    }, {
        "name": "Vannfantom",
        "group": 1,
        "index": 4
    }, {
        "name": "Reference Dosimetry",
        "group": 1,
        "index": 5
    }, {
        "name": "Quality Control",
        "group": 1,
        "index": 6
    }, {
        "name": "Plan QA",
        "group": 1,
        "index": 7
    }, {
        "name": "Strålevern",
        "group": 1,
        "index": 8
    }, {
        "name": "kV CBCT dosimetry",
        "group": 1,
        "index": 9
    }, {
        "name": "ROOS kammer",
        "group": 2,
        "index": 10
    }, {
        "name": "Doseplan",
        "group": 2,
        "index": 11
    }, {
        "name": "Farmer kammer",
        "group": 2,
        "index": 12
    }, {
        "name": "Profil dioder",
        "group": 2,
        "index": 13
    }, {
        "name": "Diamant diode",
        "group": 2,
        "index": 14
    }, {
        "name": "Dose1 Ekektrometer",
        "group": 2,
        "index": 15
    }, {
        "name": "CC13 kammer",
        "group": 2,
        "index": 16
    }, {
        "name": "MV EPID",
        "group": 3,
        "index": 17
    }, {
        "name": "ArcCHECK",
        "group": 3,
        "index": 18
    }, {
        "name": "DoseCHECK",
        "group": 3,
        "index": 19
    }, {
        "name": "Machine QA",
        "group": 2,
        "index": 20
    }, {
        "name": "MatriXX",
        "group": 3,
        "index": 21
    }, {
        "name": "Solid Water",
        "group": 3,
        "index": 22
    }, {
        "name": "Termometer",
        "group": 4,
        "index": 23
    }, {
        "name": "Barometer",
        "group": 4,
        "index": 24
    }, {
        "name": "DailyQA3",
        "group": 1,
        "index": 25
    }, {
        "name": "kV QA phantom",
        "group": 3,
        "index": 26
    }, {
        "name": "MV QA phantom",
        "group": 3,
        "index": 27
    }, {
        "name": "CatPHAN (CBCT QA)",
        "group": 3,
        "index": 28
    }, {
        "name": "Winston-Lutz QA",
        "group": 3,
        "index": 29
    }, {
        "name": "Field Size QA",
        "group": 3,
        "index": 30
    }, {
        "name": "RadCal utstyr",
        "group": 4,
        "index": 31
    }, {
        "name": "InVivo Dosimetry",
        "group": 4,
        "index": 32
    }, {
        "name": "Shielding etc.",
        "group": 4,
        "index": 33
    }, {
        "name": "Gamma SurveyMeter",
        "group": 4,
        "index": 34
    }, {
        "name": "Wendi II (neutron)",
        "group": 4,
        "index": 35
    }],
    "links": [{
        "source": 1,
        "target": 0,
        "value": 1
    }, {
        "source": 2,
        "value": 1
    }, {
        "source": 8,
        "target": 33,
        "value": 1
    }, {
        "source": 8,
        "target": 34,
        "value": 1
    }, {
        "source": 8,
        "target": 35,
        "value": 1
    }]
}



'''
http = urllib3.PoolManager(num_pools=3)
req = http.request("GEET","https://raw.githubusercontent.com/plotly/datasets/master/miserables.json")
#opener = urllib2.build_opener()
#f = opener.open(req)
dataX = req.data.decode("utf-8")
print(dataX)
data = json.loads(dataX)
'''
data = dataY
print(data.keys())
N=len(data['nodes'])
L=len(data['links'])
Edges=[(data['links'][k]['source'], data['links'][k]['target']) for k in range(L)]

#print("EDGES ERROR: ", type(Edges) )
#for edge in Edges:
#  print(edge)
#print("EDGES ERROR: ", type(Edges[0]) )


G=ig.Graph(Edges, directed=False)

labels=[]
group=[]
for node in data['nodes']:
    labels.append(node['name'])
    group.append(node['group'])



layt=G.layout('kk', dim=3)


Xn=[layt[k][0] for k in range(N)]# x-coordinates of nodes
Yn=[layt[k][1] for k in range(N)]# y-coordinates
Zn=[layt[k][2] for k in range(N)]# z-coordinates
Xe=[]
Ye=[]
Ze=[]
for e in Edges:
    Xe+=[layt[e[0]][0],layt[e[1]][0], None]# x-coordinates of edge ends
    Ye+=[layt[e[0]][1],layt[e[1]][1], None]
    Ze+=[layt[e[0]][2],layt[e[1]][2], None]


trace1=go.Scatter3d(x=Xe,
               y=Ye,
               z=Ze,
               mode='lines',
               line=dict(color='rgb(125,125,125)', width=1),
               hoverinfo='none'
               )

trace2=go.Scatter3d(x=Xn,
               y=Yn,
               z=Zn,
               mode='markers+text',
               name='actors',
               marker=dict(symbol='circle',
                             size=6,
                             color=group,
                             colorscale='Viridis',
                             line=dict(color='rgb(50,50,50)', width=0.5)
                             ),
               text=labels,
               hoverinfo='text'
               )

axis=dict(showbackground=False,
          showline=False,
          zeroline=False,
          showgrid=False,
          showticklabels=False,
          title=''
          )

layout = go.Layout(
         title="Network of dosimetry ralted concepts and tools at RAD (3D visualization)",
         width=1000,
         height=1000,
         showlegend=False,
         scene=dict(
             xaxis=dict(axis),
             yaxis=dict(axis),
             zaxis=dict(axis),
        ),
     margin=dict(
        t=100
    ),
    hovermode='closest',
    annotations=[
           dict(
           showarrow=False,
            text="Data source: <a href='K:\Felles\KRE\AMF\Dosimetri og QA\vedlikehold\'> . t.b.c. </a>",
            xref='paper',
            yref='paper',
            x=0,
            y=0.1,
            xanchor='left',
            yanchor='bottom',
            font=dict(
            size=14
            )
            )
        ],    )


data=[trace1, trace2]
fig=go.Figure(data=data, layout=layout)

py.offline.iplot(fig, filename='Los-Ys')
#py.offline.plot(fig, filename='los-Ys.html')
#from google.colab import files
#files.download('los-Ys.html')
# Out:
# dict_keys(['nodes', 'links'])
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
